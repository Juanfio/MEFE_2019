# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import random as rm
import math

# %% [markdown]
# # Punto 1

# %%
p = 0.6
suma1 = 0
suma2 = 0
N = 100000
for i in range (N):
    a = rm.uniform(0,1)
    if 0 <= a < p: #Intervalo [0,p) ; tiene probabilidad p.
        suma1 = suma1 + 1
    elif p <= a < 1: #Intervalo [1,p) ; tiene probabilidad 1 - p.
        suma2 = suma2 + 1
print (suma1/N)
print (suma2/N)
# Out:
# 0.59813
# 0.40187

# %%
# n : Número de repeticiones. p: Probabilidad de que ocurra.
# La probabilidad de que la var_alea sea menor a p es p. Por ende voy a tener una cantidad de exitos dada por esa probabilidad.
# Es decir, si tengo 50% de probabilidades de tener un éxito, este código da como resultado que "exitos" es igual al 50% de n. 
def ensayo_jakob (n,p):
    exitos = 0
    for i in range (n):
        var_alea = rm.uniform (0,1)
        if var_alea < p:
            exitos = exitos + 1
    return exitos

print (ensayo_jakob (1000,0.5))
# Out:
# 498

# %% [markdown]
# # Punto 2

# %%
n_fotones = 15
e_detector = 0.75
N = 1000

fotones_detectados = []
for _ in range (N):
    fotones_detectados.append(ensayo_jakob (n_fotones,e_detector)) 
# Como número de repeticiones ponemos el nro de fotones y en probabilidad del evento la eficiencia del detector, porque el evento
# observado es si el fotón que llega al detector es observado o no; esto ocurre n_fotones veces con una probabilidad e_detector.

    
_, ax = plt.subplots()
# Para graficar el histograma.
alt, anch, _ = plt.hist (fotones_detectados, edgecolor = "black", normed = True)
plt.xlabel ("Número de Fotones detectados")
plt.ylabel ("Veces que ocurrió")
plt.title ("Punto 2")

# Para escribir la desviación estandar de la Binomial.
sigma =  stats.binom.std (n_fotones,e_detector)
textstr = r'$\sigma=%.2f$' % (sigma, )
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top')

# Para graficar la función binomial.
x = np.arange (1,n_fotones+1)
y = []
for i in range (1,n_fotones+1):
    y.append(stats.binom.pmf (i,n_fotones,e_detector))
plt.plot (x,y)

#Para dibujar el error.
centrobin = 0.5*(anch[1:]+anch[:-1]) 
# El array "anch" tiene 1 elemento mas que el array "alt". Toma en cuenta los extremos. Tomo el centro del bin.
sigma_histograma = []
for i in range (len(alt)):
    sigma_histograma.append(math.sqrt(N*alt[i]*(1-alt[i]))/N)

plt.errorbar (centrobin,alt,yerr = sigma_histograma, fmt = " .r") 

plt.show ()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # Punto 3

# %%
I = 15
n = 1000
dt = 1/n
p = I * dt

N = 1000
fotones_emitidos = []
for _ in range (N): # Lo que estoy diciendo aca es que el experimento de ver lo que pasa en 1s lo repito 1000 veces.
    fotones_emitidos.append(ensayo_jakob (n,p))
# La fuente emite con una probabilidad p en un dt un foton. Quiero ver cuantos emitio (exitos) en un segundo. Como dt es 1/1000,
# en un segundo hay 1000 dt entonces el evento sucede 1000 veces, y voy sumando los exitos. Al final luego de las 1000 
# repeticiones, tengo una lista con la cantidad de fotones que se emitieron en cada segundo.


_, ax = plt.subplots()
# Para graficar el histograma.
alt, anch, _ = plt.hist (fotones_emitidos, edgecolor = "black", normed = True)
plt.xlabel ("Número de Fotones emitidos")
plt.ylabel ("Veces que ocurrió")
plt.title ("Punto 3")

# Para escribir la desviación estandar de la Poisson.
mu = I
sigma = stats.poisson.std (mu)
textstr = r'$\sigma=%.2f$' % (sigma, )
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top')

# Para graficar la poisson.
x = np.arange(0,max(fotones_emitidos)+1)
y = stats.poisson.pmf(x,mu)

plt.plot (x,y)

#Para dibujar el error.
centrobin = 0.5*(anch[1:]+anch[:-1])
sigma_histograma = []
for i in range (len(alt)):
    sigma_histograma.append(math.sqrt(N*alt[i]*(1-alt[i]))/N)

plt.errorbar (centrobin,alt,yerr = sigma_histograma, fmt = " .r") 

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# 1. Es valido utilizar un programa que simula ensayos de bernoulli porque este experimento tiene dos resultados posibles; éxitos (emitió fotón en dt) y fracasos (no emitió fotón en dt).
# 2. Siempre se puede asumir que como mucho se emitirá un solo fotón en ese dado intervalo, porque como este lo elijo yo, uno siempre puede asumir que el intervalo es suficientemente chico como para incluir solo un éxito del fenómeno observado.
# 3. Se puede aproximar utilizando Poisson porque:
#     a) Se tomó un intervalo de tiempo suficientemente chico como para asumir que como mucho solo se emite un fotón en este.
#     b) La probabilidad de encontrarlo es proporcional al diferencial de tiempo.
#     c) La probabilidad de encontrar un fotón en el primer dt es independiente de encontrarlo en los dt siguientes.
# 4. Debido a estos tres items, se cumplen las hipótesis necesarias para la Poisson.

# %% [markdown]
# # Punto 4

# %%
I = 15
n = 1000
dt = 1/n
p = I * dt
e_detector = 0.75

N = 1000
fotones_detectados = []
fotones_emitidos = []
for _ in range (N): 
    fot_emit_1s = ensayo_jakob (n,p)
    fotones_emitidos.append(fot_emit_1s) #fotones emitidos en 1s.
    fotones_detectados.append(ensayo_jakob (fot_emit_1s,e_detector))# Analizo cuantos del número de fotones emitidos en este
    # segundo fueron detectados. Esto lo realizo N veces.
    
    
_, ax = plt.subplots()
# Para graficar el histograma.
alt, anch, _ = plt.hist (fotones_detectados, edgecolor = "black", normed = True)
plt.xlabel ("Número de Fotones detectados")
plt.ylabel ("Veces que ocurrió")
plt.title ("Punto 4")

# Para escribir la desviación estandar de la Poisson.
fot_emit_promedio = sum(fotones_emitidos)/len(fotones_emitidos)
mu = e_detector * fot_emit_promedio
print (fot_emit_promedio)
# Para calcular el mu, se tiene que multiplicar la probabilidad de que suceda el evento y el número de repeticiones. El evento
# de detectar un fotón tiene una probabilidad dada por la eficiencia del detector y el número de repeticiones varía 
# cada vez que se realiza el experimento porque no se emite la misma cantidad de fotones en cada segundo, por eso en el "for" 
# anterior se tuvo en cuenta los fotones emitidos segundo a segundo. Debido a esto se tuvo en cuenta el número de repeticiones
# (i.e. de fotones emitidos) promedio, para calcular el mu.

sigma =  stats.poisson.std (mu)
textstr = r'$\sigma=%.2f$' % (sigma, )
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top')

# Para graficar la Poisson.
x = np.arange(0,max(fotones_detectados)+1)
y = stats.poisson.pmf(x,mu)

plt.plot (x,y)

#Para dibujar el error.
centrobin = 0.5*(anch[1:]+anch[:-1])
sigma_histograma = []
for i in range (len(alt)):
    sigma_histograma.append(math.sqrt(N*alt[i]*(1-alt[i]))/N)

plt.errorbar (centrobin,alt,yerr = sigma_histograma, fmt = " .r") 

plt.show ()
# Out:
# 14.843
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# 1. Se grafico una Poisson para la combinación de emisión y detección de fotones, debido a que la emisión cumple una distribución Poisson, la detección una Binomial y la composición de ambas (que es lo que realizó al combinar ambos fenómenos) da una Poisson.

# %% [markdown]
# # Punto 5

# %%
I = 15
n = 1000 # Subdivisiones de 1 segundo.
dt = 1/n

p_emit = I * dt # Esta es la proba de emitir un foton en tiempo dt.
p_detec = 0.75 # La eficiencia del detector es la probabilidad de detectarlo.

p_efect = p_emit * p_detec # La proba efectiva es la de emitirlo Y detectarlo.

N = 1000
fotones_detectados = []
for _ in range (N):
    fotones_detectados.append(ensayo_jakob (n,p_efect)) 
# En un dt tengo dos eventos la emisión de un fotón (con proba p_emit) y su detección (con proba p_detec), en un segundo eso 
# sucede 1000 veces. Para cada iteración del "for", suceden ambos eventos con probabilidad p_efect. Registrándose la cantidad
# de fotones detectados en cada segundo.

_, ax = plt.subplots()
# Para graficar el histograma.
alt, anch, _ = plt.hist (fotones_detectados, edgecolor = "black", normed = True)
plt.xlabel ("Número de Fotones detectados")
plt.ylabel ("Veces que ocurrió")
plt.title ("Punto 5")

# Para escribir la desviación estandar de la Poisson.
mu = p_efect * n
sigma =  stats.poisson.std (mu)
textstr = r'$\sigma=%.2f$' % (sigma, )
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top')

# Para graficar la función Poisson.
x = np.arange(0,max(fotones_detectados)+1)
y = stats.poisson.pmf(x,mu)

plt.plot (x,y)

#Para dibujar el error.
centrobin = 0.5*(anch[1:]+anch[:-1])
sigma_histograma = []
for i in range (len(alt)):
    sigma_histograma.append(math.sqrt(N*alt[i]*(1-alt[i]))/N)

plt.errorbar (centrobin,alt,yerr = sigma_histograma, fmt = " .r") 

plt.show ()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# 1. La probabilidad efectiva se calculo multiplicando la probabilidad de emitir un fotón con la probabilidad de detectarlo, porque tienen que pasar ambos eventos. Se tiene que emitir un fotón *y* se tiene que detectar.
#
# 2. Si bien la desviación estandar y la esperanza de ambas curvas (punto 4 y 5) no son iguales (difieren a lo sumo por 0.01), esto se debe a que se tuvo en cuenta para el número de repeticiones promedio que la cantidad de fotones emitidos no era siempre la misma (punto 4). Mas allá de esto, se puede observar que ambos resultados son iguales.

# %% [markdown]
# # Punto 6

# %% [markdown]
# 1. La probabilidad de tener de N eventos, n en un dado bin y el resto (N-n) en los otros bins, viene dada por una Binomial; ya que tenemos dos posibles resultados (esta en ese bin o no esta).
#
# 2. En cuanto a las discrepancias entre la curva teórica y los histogramas, en todos los casos se observa que al aumentar el número de fotones enviados (i.e. aumentar la intensidad de la fuente) la discrepancia disminuye.
